# %% [markdown]
# # **House Price Prediction Project**

# %% [markdown]
# ## Author
# Abraham KOLOBOE
# * Email : <abklb27@gmail.com>
# * Linkedin : [Abraham KOLOBOE](https://www.linkedin.com/in/abraham-koloboe-630683263)
#
# This project aims to predict house prices using the "House Price Prediction" dataset. The PyCaret framework was employed to streamline the creation, training, and evaluation of prediction models.
#
# ## Project Description
# The primary objective of this project is to develop a model capable of accurately predicting house prices based on various features. The "House Price Prediction" dataset contains information about different characteristics of houses along with their corresponding prices. This project explores how to leverage PyCaret to automate the modeling and evaluation process.
#
# ## Prerequisites
# Make sure you have Python 3.x installed along with the following libraries:
#
# * PyCaret
# * Pandas
# * Numpy
# * Matplotlib
# * Seaborn
#
# Install the dependencies by running:
#
#
# * pip install pycaret pandas numpy matplotlib seaborn
#
# ## About PyCaret
# PyCaret is an open-source machine learning library that greatly simplifies the process of model creation, selection, training, and evaluation. It provides a user-friendly interface for performing complex tasks such as data preparation, feature selection, model comparison, and hyperparameter optimization.

# %% [markdown]
# # Install PyCaret

# %%
! pip install -U --pre pycaret

# %% [markdown]
# # Import libraries

# %%
import pycaret
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Load data

# %%
data = pd.read_csv("Housing.csv")
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0                no             yes        2      yes        furnished
# 1                no             yes        3       no        furnished
# 2                no              no        2      yes   semi-furnished
# 3                no             yes        3      yes        furnished
# 4                no             yes        2       no        furnished
# ..              ...             ...      ...      ...              ...
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished
#
# [545 rows x 13 columns]

# %% [markdown]
# # Description of data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %% [markdown]
# ## Data's summary

# %%
data.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *['price'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_1, *['area'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_2, *['bedrooms'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_3, *['bathrooms'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_4, *['price'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_5, *['area'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_6, *['bedrooms'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_7, *['bathrooms'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 6 * figscale, 6 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(_df_8, *[[['price', 'area'], ['area', 'bedrooms'], ['bedrooms', 'bathrooms'], ['bathrooms', 'stories']]], **{})
# chart
# ERROR:root:Did not find quickchart key chart-f0c09db8-09a6-4cd5-a90f-9b30d190ba55 in chart cache
# ERROR:root:Did not find quickchart key chart-2e317a0a-a512-47de-afe2-f3c26c00d93f in chart cache

# %% [markdown]
# ## Missing values

# %%
data.isna().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %% [markdown]
# * No missing values on this dataset

# %% [markdown]
# # Visualization of our dataset

# %% [markdown]
# ## Pairplot

# %%
sns.pairplot(data);

# %% [markdown]
# ## Plot histograms and distribution of our variables

# %% [markdown]
# ### Separate numeric and categorical variables

# %%
numeric_features = (list(data.select_dtypes("int64").columns))
categorical_features = list(data.select_dtypes("object").columns)

print(f'Variables numériques :\n{numeric_features}\n\nVariables catégorielles:\n{categorical_features}')
# Out:
# Variables numériques :
# ['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'parking']
#
# Variables catégorielles:
# ['mainroad', 'guestroom', 'basement', 'hotwaterheating', 'airconditioning', 'prefarea', 'furnishingstatus']

# %% [markdown]
# ### Distributions

# %%
for feature in numeric_features:
    plt.figure()
    sns.displot(data[feature])
    plt.xticks(rotation=90)
    plt.xlabel(feature)
    plt.ylabel('Frequency')
    plt.title(f'Distribution of {feature}')
    plt.show()

# %% [markdown]
# ### Histrograms

# %%
for feature in categorical_features:
    plt.figure(figsize=(10,4))
    sns.histplot(data[feature])
    plt.xticks(rotation=90)
    plt.xlabel(feature)
    plt.ylabel('Frequency')
    plt.title(f'Histogram of {feature}')
    plt.show()

# %% [markdown]
# # Create a setup for regresssion

# %%
from pycaret.regression import *
s = setup(data, target = 'price', session_id = 123)
# Out:
# <style type="text/css">
# #T_ba168_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ba168" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba168_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ba168_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba168_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ba168_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ba168_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_ba168_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ba168_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ba168_row1_col1" class="data row1 col1" >price</td>
#     </tr>
#     <tr>
#       <th id="T_ba168_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ba168_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_ba168_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_ba168_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ba168_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_ba168_row3_col1" class="data row3 col1" >(545, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_ba168_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ba168_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_ba168_row4_col1" class="data row4 col1" >(545, 15)</td>
#     </tr>
#     <tr>
#       <th id="T_ba168_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ba168_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_ba168_row5_col1" class="data row5 col1" >(381, 15)</td>
#     </tr>
#     <tr>
#       <th id="T_ba168_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ba168_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_ba168_row6_col1" class="data row6 col1" >(164, 15)</td>
#     </tr>
#     <tr>
#       <th id="T_ba168_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ba168_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_ba168_row7_col1" class="data row7 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_ba168_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ba168_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_ba168_row8_col1" class="data row8 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_ba168_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ba168_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_ba168_row9_col1" class="data row9 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_ba168_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ba168_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_ba168_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ba168_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ba168_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_ba168_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_ba168_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ba168_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_ba168_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_ba168_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_ba168_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_ba168_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_ba168_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_ba168_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_ba168_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_ba168_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_ba168_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_ba168_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_ba168_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_ba168_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_ba168_row16_col1" class="data row16 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_ba168_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_ba168_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_ba168_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_ba168_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_ba168_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_ba168_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_ba168_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_ba168_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_ba168_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ba168_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_ba168_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_ba168_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ba168_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_ba168_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_ba168_row21_col1" class="data row21 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_ba168_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_ba168_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_ba168_row22_col1" class="data row22 col1" >fa70</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Train models

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_6c1de th {
#   text-align: left;
# }
# #T_6c1de_row0_col0, #T_6c1de_row1_col0, #T_6c1de_row1_col1, #T_6c1de_row1_col2, #T_6c1de_row1_col3, #T_6c1de_row1_col4, #T_6c1de_row1_col5, #T_6c1de_row1_col6, #T_6c1de_row2_col0, #T_6c1de_row2_col1, #T_6c1de_row2_col2, #T_6c1de_row2_col3, #T_6c1de_row2_col4, #T_6c1de_row2_col5, #T_6c1de_row2_col6, #T_6c1de_row3_col0, #T_6c1de_row3_col1, #T_6c1de_row3_col2, #T_6c1de_row3_col3, #T_6c1de_row3_col4, #T_6c1de_row3_col5, #T_6c1de_row3_col6, #T_6c1de_row4_col0, #T_6c1de_row4_col1, #T_6c1de_row4_col2, #T_6c1de_row4_col3, #T_6c1de_row4_col4, #T_6c1de_row4_col5, #T_6c1de_row4_col6, #T_6c1de_row5_col0, #T_6c1de_row5_col1, #T_6c1de_row5_col2, #T_6c1de_row5_col3, #T_6c1de_row5_col4, #T_6c1de_row5_col5, #T_6c1de_row5_col6, #T_6c1de_row6_col0, #T_6c1de_row6_col1, #T_6c1de_row6_col2, #T_6c1de_row6_col3, #T_6c1de_row6_col4, #T_6c1de_row6_col5, #T_6c1de_row6_col6, #T_6c1de_row7_col0, #T_6c1de_row7_col1, #T_6c1de_row7_col2, #T_6c1de_row7_col3, #T_6c1de_row7_col4, #T_6c1de_row7_col5, #T_6c1de_row7_col6, #T_6c1de_row8_col0, #T_6c1de_row8_col1, #T_6c1de_row8_col2, #T_6c1de_row8_col3, #T_6c1de_row8_col4, #T_6c1de_row8_col5, #T_6c1de_row8_col6, #T_6c1de_row9_col0, #T_6c1de_row9_col1, #T_6c1de_row9_col2, #T_6c1de_row9_col3, #T_6c1de_row9_col4, #T_6c1de_row9_col5, #T_6c1de_row9_col6, #T_6c1de_row10_col0, #T_6c1de_row10_col1, #T_6c1de_row10_col2, #T_6c1de_row10_col3, #T_6c1de_row10_col4, #T_6c1de_row10_col5, #T_6c1de_row10_col6, #T_6c1de_row11_col0, #T_6c1de_row11_col1, #T_6c1de_row11_col2, #T_6c1de_row11_col3, #T_6c1de_row11_col4, #T_6c1de_row11_col5, #T_6c1de_row11_col6, #T_6c1de_row12_col0, #T_6c1de_row12_col1, #T_6c1de_row12_col2, #T_6c1de_row12_col3, #T_6c1de_row12_col4, #T_6c1de_row12_col5, #T_6c1de_row12_col6, #T_6c1de_row13_col0, #T_6c1de_row13_col1, #T_6c1de_row13_col2, #T_6c1de_row13_col3, #T_6c1de_row13_col4, #T_6c1de_row13_col5, #T_6c1de_row13_col6, #T_6c1de_row14_col0, #T_6c1de_row14_col1, #T_6c1de_row14_col2, #T_6c1de_row14_col3, #T_6c1de_row14_col4, #T_6c1de_row14_col5, #T_6c1de_row14_col6, #T_6c1de_row15_col0, #T_6c1de_row15_col1, #T_6c1de_row15_col2, #T_6c1de_row15_col3, #T_6c1de_row15_col4, #T_6c1de_row15_col5, #T_6c1de_row15_col6, #T_6c1de_row16_col0, #T_6c1de_row16_col1, #T_6c1de_row16_col2, #T_6c1de_row16_col3, #T_6c1de_row16_col4, #T_6c1de_row16_col5, #T_6c1de_row16_col6, #T_6c1de_row17_col0, #T_6c1de_row17_col1, #T_6c1de_row17_col2, #T_6c1de_row17_col3, #T_6c1de_row17_col4, #T_6c1de_row17_col5, #T_6c1de_row17_col6, #T_6c1de_row18_col0, #T_6c1de_row18_col1, #T_6c1de_row18_col2, #T_6c1de_row18_col3, #T_6c1de_row18_col4, #T_6c1de_row18_col5, #T_6c1de_row18_col6 {
#   text-align: left;
# }
# #T_6c1de_row0_col1, #T_6c1de_row0_col2, #T_6c1de_row0_col3, #T_6c1de_row0_col4, #T_6c1de_row0_col5, #T_6c1de_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_6c1de_row0_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_6c1de_row1_col7, #T_6c1de_row2_col7, #T_6c1de_row3_col7, #T_6c1de_row4_col7, #T_6c1de_row5_col7, #T_6c1de_row6_col7, #T_6c1de_row7_col7, #T_6c1de_row8_col7, #T_6c1de_row9_col7, #T_6c1de_row10_col7, #T_6c1de_row11_col7, #T_6c1de_row12_col7, #T_6c1de_row13_col7, #T_6c1de_row14_col7, #T_6c1de_row15_col7, #T_6c1de_row16_col7, #T_6c1de_row17_col7, #T_6c1de_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_6c1de" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c1de_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6c1de_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_6c1de_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_6c1de_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_6c1de_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_6c1de_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_6c1de_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_6c1de_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c1de_level0_row0" class="row_heading level0 row0" >ridge</th>
#       <td id="T_6c1de_row0_col0" class="data row0 col0" >Ridge Regression</td>
#       <td id="T_6c1de_row0_col1" class="data row0 col1" >783284.7624</td>
#       <td id="T_6c1de_row0_col2" class="data row0 col2" >1108456709962.6086</td>
#       <td id="T_6c1de_row0_col3" class="data row0 col3" >1028322.0387</td>
#       <td id="T_6c1de_row0_col4" class="data row0 col4" >0.6701</td>
#       <td id="T_6c1de_row0_col5" class="data row0 col5" >0.2123</td>
#       <td id="T_6c1de_row0_col6" class="data row0 col6" >0.1748</td>
#       <td id="T_6c1de_row0_col7" class="data row0 col7" >0.2930</td>
#     </tr>
#     <tr>
#       <th id="T_6c1de_level0_row1" class="row_heading level0 row1" >lr</th>
#       <td id="T_6c1de_row1_col0" class="data row1 col0" >Linear Regression</td>
#       <td id="T_6c1de_row1_col1" class="data row1 col1" >785303.0816</td>
#       <td id="T_6c1de_row1_col2" class="data row1 col2" >1109722958860.8826</td>
#       <td id="T_6c1de_row1_col3" class="data row1 col3" >1029276.1106</td>
#       <td id="T_6c1de_row1_col4" class="data row1 col4" >0.6694</td>
#       <td id="T_6c1de_row1_col5" class="data row1 col5" >0.2126</td>
#       <td id="T_6c1de_row1_col6" class="data row1 col6" >0.1752</td>
#       <td id="T_6c1de_row1_col7" class="data row1 col7" >0.8880</td>
#     </tr>
#     <tr>
#       <th id="T_6c1de_level0_row2" class="row_heading level0 row2" >lasso</th>
#       <td id="T_6c1de_row2_col0" class="data row2 col0" >Lasso Regression</td>
#       <td id="T_6c1de_row2_col1" class="data row2 col1" >785302.3289</td>
#       <td id="T_6c1de_row2_col2" class="data row2 col2" >1109723228869.1519</td>
#       <td id="T_6c1de_row2_col3" class="data row2 col3" >1029276.0099</td>
#       <td id="T_6c1de_row2_col4" class="data row2 col4" >0.6694</td>
#       <td id="T_6c1de_row2_col5" class="data row2 col5" >0.2126</td>
#       <td id="T_6c1de_row2_col6" class="data row2 col6" >0.1752</td>
#       <td id="T_6c1de_row2_col7" class="data row2 col7" >0.5800</td>
#     </tr>
#     <tr>
#       <th id="T_6c1de_level0_row3" class="row_heading level0 row3" >lar</th>
#       <td id="T_6c1de_row3_col0" class="data row3 col0" >Least Angle Regression</td>
#       <td id="T_6c1de_row3_col1" class="data row3 col1" >785303.0816</td>
#       <td id="T_6c1de_row3_col2" class="data row3 col2" >1109722958860.8833</td>
#       <td id="T_6c1de_row3_col3" class="data row3 col3" >1029276.1106</td>
#       <td id="T_6c1de_row3_col4" class="data row3 col4" >0.6694</td>
#       <td id="T_6c1de_row3_col5" class="data row3 col5" >0.2126</td>
#       <td id="T_6c1de_row3_col6" class="data row3 col6" >0.1752</td>
#       <td id="T_6c1de_row3_col7" class="data row3 col7" >0.5240</td>
#     </tr>
#     <tr>
#       <th id="T_6c1de_level0_row4" class="row_heading level0 row4" >llar</th>
#       <td id="T_6c1de_row4_col0" class="data row4 col0" >Lasso Least Angle Regression</td>
#       <td id="T_6c1de_row4_col1" class="data row4 col1" >785302.2833</td>
#       <td id="T_6c1de_row4_col2" class="data row4 col2" >1109722991820.3098</td>
#       <td id="T_6c1de_row4_col3" class="data row4 col3" >1029275.8882</td>
#       <td id="T_6c1de_row4_col4" class="data row4 col4" >0.6694</td>
#       <td id="T_6c1de_row4_col5" class="data row4 col5" >0.2126</td>
#       <td id="T_6c1de_row4_col6" class="data row4 col6" >0.1752</td>
#       <td id="T_6c1de_row4_col7" class="data row4 col7" >0.4400</td>
#     </tr>
#     <tr>
#       <th id="T_6c1de_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_6c1de_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_6c1de_row5_col1" class="data row5 col1" >807609.1866</td>
#       <td id="T_6c1de_row5_col2" class="data row5 col2" >1239279313262.8608</td>
#       <td id="T_6c1de_row5_col3" class="data row5 col3" >1085875.8015</td>
#       <
# Processing:   0%|          | 0/81 [00:00<?, ?it/s]

# %% [markdown]
# **The best model here is Ridge Regression model**

# %% [markdown]
# # Analyze model

# %% [markdown]
# ## Residuals of model

# %%
plot_model(best_model, plot = 'residuals')

# %% [markdown]
# ## Error of model

# %%
plot_model(best_model, plot = 'error')

# %% [markdown]
# ## Feature importance

# %%
plot_model(best_model, plot = 'feature')

# %% [markdown]
# # Save our pipeline model

# %%
save_model(best_model, 'House price predictor')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=/tmp/joblib),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['area', 'bedrooms', 'bathrooms',
#                                               'stories', 'parking'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['mainroad', 'guestroom',
#                                               'basement', 'hotwaterheating',
#                                               'airconditioning', 'prefarea',
#                                               'furnishingstatus'],
#                                      transformer=...
#                                                                           'data_type': dtype('O'),
#                                                                           'mapping': no     0
#  yes    1
#  NaN   -1
#  dtype: int64},
#                                                                          {'col': 'prefarea',
#                                                                           'data_type': dtype('O'),
#                                                                           'mapping': no     0
#  yes    1
#  NaN   -1
#  dtype: int64}]))),
#                  ('onehot_encoding',
#                   TransformerWrapper(include=['furnishingstatus'],
#                                      transformer=OneHotEncoder(cols=['furnishingstatus'],
#                                                                handle_missing='return_nan',
#                                                                use_cat_names=True))),
#                  ('trained_model', Ridge(random_state=123))]),
#  'House price predictor.pkl')

# %% [markdown]
# # Load our model

# %%
loaded_best_pipeline = load_model('House price predictor')
loaded_best_pipeline
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=FastMemory(location=/tmp/joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['area', 'bedrooms', 'bathrooms',
#                                              'stories', 'parking'],
#                                     transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransformerWrapper(include=['mainroad', 'guestroom',
#                                              'basement', 'hotwaterheating',
#                                              'airconditioning', 'prefarea',
#                                              'furnishingstatus'],
#                                     transformer=...
#                                                                          'data_type': dtype('O'),
#                                                                          'mapping': no     0
# yes    1
# NaN   -1
# dtype: int64},
#                                                                         {'col': 'prefarea',
#                                                                          'data_type': dtype('O'),
#                                                                          'mapping': no     0
# yes    1
# NaN   -1
# dtype: int64}]))),
#                 ('onehot_encoding',
#                  TransformerWrapper(include=['furnishingstatus'],
#                                     transformer=OneHotEncoder(cols=['furnishingstatus'],
#                                                               handle_missing='return_nan',
#                                                               use_cat_names=True))),
#                 ('trained_model', Ridge(random_state=123))])

# %% [markdown]
# # Use model to make predictions

# %% [markdown]
# ## Make a copy of our dataset

# %%
new_data = data.copy()
new_data.drop('price', axis=1, inplace=True)
new_data.head()
# Out:
#    area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  7420         4          2        3      yes        no       no
# 1  8960         4          4        4      yes        no       no
# 2  9960         3          2        2      yes        no      yes
# 3  7500         4          2        2      yes        no      yes
# 4  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %% [markdown]
# ## Make predictions

# %%
predictions = predict_model(loaded_best_pipeline, data = new_data)
predictions.head()
# Out:
#    area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  7420         4          2        3      yes        no       no
# 1  8960         4          4        4      yes        no       no
# 2  9960         3          2        2      yes        no      yes
# 3  7500         4          2        2      yes        no      yes
# 4  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus  \
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished
#
#    prediction_label
# 0      8.056138e+06
# 1      1.040967e+07
# 2      7.692816e+06
# 3      8.197918e+06
# 4      6.698505e+06

# %% [markdown]
# ## Compare predictions and real price

# %%
real_vs_pred = pd.DataFrame([data["price"], predictions["prediction_label"]]).T
real_vs_pred
# Out:
#           price  prediction_label
# 0    13300000.0      8.056138e+06
# 1    12250000.0      1.040967e+07
# 2    12250000.0      7.692816e+06
# 3    12215000.0      8.197918e+06
# 4    11410000.0      6.698505e+06
# ..          ...               ...
# 540   1820000.0      3.156349e+06
# 541   1767150.0      2.390136e+06
# 542   1750000.0      2.603167e+06
# 543   1750000.0      2.545672e+06
# 544   1750000.0      3.163564e+06
#
# [545 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(real_vs_pred, *['price'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(real_vs_pred, *['prediction_label'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(real_vs_pred, *['price'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(real_vs_pred, *['prediction_label'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 6 * figscale, 6 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(real_vs_pred, *[[['price', 'prediction_label']]], **{})
# chart

# %% [markdown]
# ## Visualize Prediction vs Reality

# %%
import matplotlib.pyplot as plt

real_price = data['price']
predicted_price = predictions["prediction_label"]

# Create a graphic
plt.figure(figsize=(12, 6))

# Plot real price in blue
plt.plot(real_price, label='Real Price', color='blue', marker='o')

# Plot predicted price in red
plt.plot(predicted_price, label='Predicted Price', color='red', marker='x')

# Legends and title
plt.xlabel('Samples')
plt.ylabel('Price')
plt.title('Real House Prices vs. Predicted House Prices')
plt.legend()

# Show graphic
plt.show()
